# %% [markdown]
# # pandas 실습 과제 (7/17)
#
# ## 타이타닉 데이터셋
#
# 1. `seaborn.load_dataset('titanic')` 함수를 이용해 타이타닉 데이터셋을 불러와 데이터프레임으로 저장하세요.
#
# 2. 데이터프레임(df)의 처음과 마지막 5개의 로우를 각각 출력하세요.
#
# 3. 데이터프레임(df)이 몇 개의 로우와 행으로 이루어져 있는지 구조(shape)를 확인하세요.
#
# 4. 데이터프레임(df)의 평균, 표준편차, 사분위수 등 주요 통계 지표를 확인하세요.
#
# 5. 데이터프레임(df)에 몇 개의 컬럼이 있는지, 각 컬럼에 포함된 데이터들의 타입은 무엇인지 확인해보세요.
#
# 6. 결측치 확인하기
#
# 7. 'Age'의 결측치를 중앙값으로 채우고 확인하기
#
# 8. 'embarked'과 'embark_town'의 결측치를 최빈값으로 채우기
#
# 9. 결측치가 많은 'deck' 열 제거하기
#
# 10. 결측치 여부 확인하기
#
# 11. 성별에 따른 살아남은 사람의 합계, 평균을 각각 구하시오.
#
# 12. 좌석 등급에 따른 살아남은 사람의 수와 평균을 각각 구하시오.
#
# 13. 좌석 등급별 평균 요금을 구하시오.
#
# 14. 생존한 승객들의 정보를 나타내시오.
#
# 15. 생존한 여성 승객들을 나타내시오
#
# 16. 'fare' 열로 정렬하고 상위 10개 항목을 표시하여라
#
# 17. Map을 사용하여 `Embarked' 열을 전체 이름으로 변환하세요.
#
# 18. Apply와 Lambda를 사용하여 'Fare'가 50 이상인 경우 'Expensive'로, 그렇지 않은 경우 'Cheap'으로 분류하는 'FareCategory' 열을 생성하세요.
#
# 19. Pivot Table을 사용하여 각 'Sex'와 'Pclass' 조합별 평균 'Age'를 계산하세요.
#
# ### 데이터 만들기 실습
# 20. 다음 두 개의 표를 데이터프레임으로 생성하고, 두 데이터프레임을 하나의 데이터프레임으로 합쳐보세요.
# - left
# - right
# - inner
# - outer
# - cross

# %%
# 패키지 불러오기
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### 1. `seaborn.load_dataset('titanic')` 함수를 이용해 타이타닉 데이터셋을 불러와 데이터프레임으로 저장하세요.

# %% [markdown]
# #### 2. 데이터프레임(df)의 처음과 마지막 5개의 로우를 각각 출력하세요.
# - `head` and `tail`

# %% [markdown]
# #### 3. 데이터프레임(df)이 몇 개의 로우와 행으로 이루어져 있는지 구조(shape)를 확인하세요.
# - `shape`

# %% [markdown]
# #### 4. 데이터프레임(df)의 평균, 표준편차, 사분위수 등 주요 통계 지표를 확인하세요.
# - `describe`

# %% [markdown]
# #### 5. 데이터프레임(df)에 몇 개의 컬럼이 있는지, 각 컬럼에 포함된 데이터들의 타입은 무엇인지 확인해보세요.
# - `info`

# %% [markdown]
# #### 6. 결측치 확인하기
# - `isnull`

# %% [markdown]
# #### 7. 'Age'의 결측치를 중앙값으로 채우고 확인하기
# - `fillna` and `median`

# %% [markdown]
# #### 8. 'embarked'과 'embark_town'의 결측치를 최빈값으로 채우기
# - `fillna` and `mode`

# %% [markdown]
# #### 9. 결측치가 많은 'deck' 열 제거하기
# - `drop`

# %% [markdown]
# #### 10. 결측치 여부 확인하기

# %% [markdown]
# #### 11. 성별에 따른 살아남은 사람의 합계, 평균을 각각 구하시오.
# - `groupby`, `sex`, `survived`

# %% [markdown]
# #### 12. 좌석 등급에 따른 살아남은 사람의 수와 평균을 각각 구하시오.
# - `reset_index` 옵션을 사용해 인덱스를 초기화하세요.
# -  `groupby`, `pclass`, `survived`

# %% [markdown]
# #### 13. 좌석 등급별 평균 요금을 구하시오.
# - `reset_index`를 이용해 데이터프레임으로 나타내시오
# - `groupby`, `pclass`, `fare`

# %% [markdown]
# #### 14. 생존한 승객들의 정보를 나타내시오.
# - 생존한 승객은 survived 열에서 1을 의미한다

# %% [markdown]
# #### 15. 생존한 여성 승객들을 나타내시오

# %% [markdown]
# #### 16. 'fare' 열로 정렬하고 상위 10개 항목을 표시하여라
# - `sort_values`

# %% [markdown]
# #### 17. Map을 사용하여 `Embarked' 열을 전체 이름으로 변환하세요.
# - `C` -> `Cherbourg`
# - `Q` -> `Queenstown`
# - `S` -> `Southampton`

# %% [markdown]
# #### 18. Apply와 Lambda를 사용하여 'Fare'가 50 이상인 경우 'Expensive'로, 그렇지 않은 경우 'Cheap'으로 분류하는 'FareCategory' 열을 생성하세요.

# %% [markdown]
# #### 19. Pivot Table을 사용하여 각 'Sex'와 'Pclass' 조합별 평균 'Age'를 계산하세요.

# %% [markdown]
# ### 다음 두 개의 표를 데이터프레임으로 생성하고, 두 데이터프레임을 하나의 데이터프레임으로 합쳐보세요.
# - left
# - right
# - inner
# - outer
# - cross

# %% [markdown]
# ![image.png](data:image/png;base64,...)
